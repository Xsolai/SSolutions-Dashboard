# %%
import pandas as pd

# %%
df = pd.read_csv("D:\XSOL.AI\SSolutions-Dashboard\\attachments\\02-Dec-2024\Softbuchung_KF.csv", sep=";")

# %%
df
# Out:
#     Auftrag Auftragsnummer (Auftrag) CRS (Standard) LT-Code  \
# 0                            7080636                   AIDA
# 1                            7081010                    MSC
# 2                            7081652                    MSC
# 3                            7081728                   AIDA
# 4                            7081894                    MSC
# 5                            7082722                    MSC
# 6                            7082797                    CST
# 7                            7083062                   AIDA
# 8                            7083597                    CST
# 9                            7083681                    CST
# 10                           7084096                   AIDA
# 11                           7084825                   AIDA
# 12                           7085216                    CST
# 13                           7085232                    CST
# 14                           7125969                    MSC
#
# ...

# %%
df.columns.str.strip()
# Out:
# Index(['Auftrag Auftragsnummer (Auftrag)', 'CRS (Standard) LT-Code',
#        'CRS (Standard) original Status', 'CRS (Standard) Status',
#        'Leistung Element Preis', 'Leistung Anlagezeit',
#        'Leistung Originalbetrag', 'Unnamed: 7'],
#       dtype='object')
