# %%
import pandas as pd

# %%
df = pd.read_csv("D:\XSOL.AI\SSolutions-Dashboard\\attachments\\11-Dec-2024\Workflow-Report-5vorFlug_daily_sales_(ID__29)-10.12.2024_00_00_(+01_00)-11.12.2024_00_00_(+01_00).csv", skiprows=[0,1,2,3], sep=";")

# %%
df.head()
# Out:
#               Mailbox   Intervall  Empfangen [#]  Neue Vorgänge [#]  \
# 0  5vF_freie_Anfragen  10.12.2024              0                  0
# 1  5vF_freie_Anfragen       Summe              0                  0
# 2        _5VF_Buchung  10.12.2024              3                  0
# 3        _5VF_Buchung       Summe              3                  0
# 4               Summe       Summe              3                  0
#
#    Gesendet [#]  Archiviert [#] Verweilzeit-Netto [∅ hh:mm:ss]  \
# 0             1               1                      147:31:56
# 1             1               1                      147:31:56
# 2             0               2                        4:18:20
# 3             0               2                        4:18:20
# 4             1               3                       75:55:08
#
#   Bearbeitungszeit [∅ Min.]  ServiceLevel-Brutto [%]  \
# 0                   0:08:41                      0.0
# 1                   0:08:41                      0.0
# ...
